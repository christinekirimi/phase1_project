# %% [markdown]
# # MICROSOFT MOVIE STUDIO PROJECT

# %% [markdown]
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies.I am charged with exploring what types of films are currently doing the best at the box office. I must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# First Step Import all the necessary Libraries I intend to use.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# In the cell below, I load ("bom.movie_gross.csv") as bom_movie_df.
#
# Domestic gross refers to gross box-office revenue from North America, USA, Canada and PuertoRico and Foreign gross refers to gross revenue from the rest of the world.

# %%
bom_movie_df = pd.read_csv("bom.movie_gross.csv")
bom_movie_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# in the cell below, I load title.basics.csv as title_basics_df.
#
# tconst(string): It is an alphanumeric unique identifier of the title. original_title is the original title,in the original language.Start_year represents the release year of a title. In the case of TV Series, it is the series start year.runtime_Minutes:primary runtime of the title, in minutes.Genres includes up to three genres associated with the title.

# %%
title_basics_df = pd.read_csv("title.basics.csv")
title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# In the cell below, I load title.ratings.csv as title_ratings_df.
#
# tconst:alphanumeric unique identifier of the title. Averagerating: weighted average of all the individual user ratings.
# numVotes: number of votes the title has received

# %%
title_ratings_df = pd.read_csv("title.ratings.csv")
title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### Checking for Null values in DIfferent Data Sets

# %% [markdown]
# The df.info() method provides us with summary metadata about our DataFrame.
# That is, it gives us data about our dataset, such as how many rows and columns it contains,
# and what data types they are stored as.

# %%
bom_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#Checking For Null Values In the Data Frame in the Studio Column
#There are 5 null values in the studios column
bom_movie_df[bom_movie_df["studio"].isna()]
# Out:
#                               title studio  domestic_gross foreign_gross  year
# 210   Outside the Law (Hors-la-loi)    NaN         96900.0       3300000  2010
# 555         Fireflies in the Garden    NaN         70600.0       3300000  2011
# 933           Keith Lemon: The Film    NaN             NaN       4000000  2012
# 1862                 Plot for Peace    NaN          7100.0           NaN  2014
# 2825               Secret Superstar    NaN             NaN     122000000  2017

# %%
#Checking for Null values the dataframe in the domestic gross column
#There are 28 missing values in the domestic gross column
bom_movie_df[bom_movie_df["domestic_gross"].isna()]
# Out:
#                                       title   studio  domestic_gross  \
# 230              It's a Wonderful Afterlife      UTV             NaN
# 298   Celine: Through the Eyes of the World     Sony             NaN
# 302                              White Lion    Scre.             NaN
# 306                        Badmaash Company     Yash             NaN
# 327                      Aashayein (Wishes)  Relbig.             NaN
# 537                                   Force     FoxS             NaN
# 713                        Empire of Silver     NeoC             NaN
# 871                            Solomon Kane     RTWC             NaN
# 928                            The Tall Man    Imag.             NaN
# 933                   Keith Lemon: The Film      NaN             NaN
# 936                     Lula, Son of Brazil     NYer             NaN
# 966                          The Cup (2012)     Myr.             NaN
# 1017                              Dark Tide      WHE             NaN
# ...

# %%
#Checking for Null values the dataframe in the foreign gross column
#There are 1350 missing values in the foreign gross column
bom_movie_df[bom_movie_df["foreign_gross"].isna()]
# Out:
#                                        title      studio  domestic_gross  \
# 222                                  Flipped          WB       1800000.0
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# 269            Grease (Sing-a-Long re-issue)        Par.        366000.0
# 280                          Last Train Home       Zeit.        288000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 222            NaN  2010
# 254            NaN  2010
# ...

# %%
#summary metadata about our DataFrame
#This dataframe has no missing values
title_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#summary metadata about our DataFrame
title_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#Checking for Null values the dataframe in the original title column
#There are 21 missing values in the original title column
title_basics_df[title_basics_df["original_title"].isna()]
# Out:
#            tconst                            primary_title original_title  \
# 39095   tt2397619               Woody Allen: A Documentary            NaN
# 58624   tt3414266                           The Outer Loop            NaN
# 62944   tt3616658                              The Hangman            NaN
# 79274   tt4548042   Urban Legend: The Blind Side Strangler            NaN
# 80116   tt4599436             Please Don't Eat the Pansies            NaN
# 82058   tt4715728                                    Regen            NaN
# 82308   tt4732998                                    Limbo            NaN
# 85353   tt4940426                                 OldZilla            NaN
# 104040  tt6092540                                 Rangreza            NaN
# 104418  tt6107024                                 The Cage            NaN
# 107378  tt6288348                         Deadly Affection            NaN
# 108971  tt6403090                     What It Takes to Win            NaN
# ...

# %%
#Checking for Null values the dataframe in the runtime_minutes column
#There are 31739 missing values in the runtime_minutes column
title_basics_df[title_basics_df["runtime_minutes"].isna()]
# Out:
#            tconst                                      primary_title  \
# 3       tt0069204                                    Sabse Bada Sukh
# 6       tt0112502                                            Bigfoot
# 8       tt0139613                                         O Silêncio
# 16      tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 21      tt0250404                                          Godfather
# ...           ...                                                ...
# 146131  tt9915790                                    Bobbyr Bondhura
# 146138  tt9916428                                The Secret of China
# 146140  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                                    Dankyavar Danka
# 146143  tt9916754                     Chico Albuquerque - Revelações
#
#                                            original_title  start_year  \
# ...

# %%
#Checking for Null values the dataframe in the genres column
#There are 5408  missing values in the genres column
title_basics_df[title_basics_df["genres"].isna()]
# Out:
#            tconst                                      primary_title  \
# 16      tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 22      tt0253093                                       Gangavataran
# 35      tt0306058                                      Second Coming
# 40      tt0326592                                      The Overnight
# 44      tt0330811                                Regret Not Speaking
# ...           ...                                                ...
# 146088  tt9907396                Footloose in the Cotswolds - Part 1
# 146089  tt9907608                Footloose in the Cotswolds - Part 2
# 146107  tt9910922       Doctor Who Augmented Reality: Times Magazine
# 146129  tt9914942                         La vida sense la Sara Amat
# 146142  tt9916730                                             6 Gunn
#
#                                            original_title  start_year  \
# ...

# %%
#Cleaning the foeign gross column: removing "," and "." using the replace method
bom_movie_df["foreign_gross"] = bom_movie_df["foreign_gross"].str.replace(',', '')
bom_movie_df["foreign_gross"] = bom_movie_df["foreign_gross"].str.replace('.', '')
bom_movie_df["foreign_gross"] = bom_movie_df["foreign_gross"].astype("float")
bom_movie_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10736\335771899.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bom_movie_df["foreign_gross"] = bom_movie_df["foreign_gross"].str.replace('.', '')
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# ...

# %%
# calculating the mean and median for the domestic gross column
dg_median = bom_movie_df["domestic_gross"].median()
print(dg_median)
dg_mean = bom_movie_df["domestic_gross"].mean()
print(dg_mean)
# Out:
# 1400000.0
# 28745845.06698422

# %%
#Replacing the misssing values in the domestic gross column with the median
bom_movie_df["domestic_gross"] = bom_movie_df["domestic_gross"].fillna(bom_movie_df["domestic_gross"].dropna().median())
bom_movie_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
# calculating the mean and median for the foreign gross column
fg_median = bom_movie_df["foreign_gross"].dropna().median()
print(fg_median)
fg_mean = bom_movie_df["foreign_gross"].dropna().mean()
print(fg_mean)
# Out:
# 18700000.0
# 74872835.30584192

# %%
#Replacing the misssing values in the foreign gross column with the median
bom_movie_df["foreign_gross"] = bom_movie_df["foreign_gross"].fillna(bom_movie_df["foreign_gross"].dropna().median())
bom_movie_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
#checking the value_counts
bom_movie_df["studio"].value_counts()
# Out:
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 257, dtype: int64

# %%
#replacing the null studio with the most common movie studio "IFC"(studio with the highest Counts)
bom_movie_df["studio"] = bom_movie_df["studio"].fillna("IFC")
bom_movie_df["studio"].value_counts()
# Out:
# IFC           171
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 257, dtype: int64

# %%
#Replacing the missing Original Title with the Primary title of the movie
title_basics_df["original_title"] = title_basics_df["original_title"].fillna(title_basics_df["primary_title"])
title_basics_df["original_title"]
# Out:
# 0                                           Sunghursh
# 1                                     Ashad Ka Ek Din
# 2                          The Other Side of the Wind
# 3                                     Sabse Bada Sukh
# 4                               La Telenovela Errante
#                              ...
# 146139                            Kuambil Lagi Hatiku
# 146140    Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141                                Dankyavar Danka
# 146142                                         6 Gunn
# 146143                 Chico Albuquerque - Revelações
# Name: original_title, Length: 146144, dtype: object

# %%
#checking for the median of runtime minutes
title_basics_df["runtime_minutes"].dropna().median()
# Out:
# 87.0

# %%
#checking for the mean of runtime minutes
title_basics_df["runtime_minutes"].dropna().mean()
# Out:
# 86.18724706088021

# %%
# replacing the missing runtime values with the median
title_basics_df["runtime_minutes"] = title_basics_df["runtime_minutes"].fillna(title_basics_df["runtime_minutes"].dropna().median())
title_basics_df["runtime_minutes"]
# Out:
# 0         175.0
# 1         114.0
# 2         122.0
# 3          87.0
# 4          80.0
#           ...
# 146139    123.0
# 146140     87.0
# 146141     87.0
# 146142    116.0
# 146143     87.0
# Name: runtime_minutes, Length: 146144, dtype: float64

# %%
# removing the rows in the genres column that have missing genres
title_basics_df = title_basics_df.dropna(subset =["genres"])
title_basics_df["genres"]
# Out:
# 0            Action,Crime,Drama
# 1               Biography,Drama
# 2                         Drama
# 3                  Comedy,Drama
# 4          Comedy,Drama,Fantasy
#                   ...
# 146138    Adventure,History,War
# 146139                    Drama
# 146140              Documentary
# 146141                   Comedy
# 146143              Documentary
# Name: genres, Length: 140736, dtype: object

# %%
#checking the title basics dataframe to ensure that it is clean
title_basics_df
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# ## DATA ANALYSIS

# %%
bom_movie_df.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.387000e+03   3.387000e+03  3387.000000
# mean     2.851978e+07   5.248331e+07  2013.958075
# std      6.675093e+07   1.100461e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.225000e+05   1.160000e+07  2012.000000
# 50%      1.400000e+06   1.870000e+07  2014.000000
# 75%      2.750000e+07   2.915000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %% [markdown]
# Answer what is the distribution of the movies by studio?

# %%
# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = bom_movie_df["studio"].value_counts()
top_10_counts = value_counts.iloc[:10]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_10_counts.index, top_10_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of movies")
ax2.set_ylabel("Count of movies")
ax1.set_title("Distribution of movies by studio")
ax2.set_title("Top 10 studios by Count of movies");

# %% [markdown]
# How many movies were produced in Each year?

# %%
# checking out the distribution of movies per year
x = bom_movie_df.groupby("year")["title"].count()
print(x)
x.plot(kind="bar",color="blue",edgecolor="black")

plt.xlabel('Year')
plt.ylabel('No of movies')
plt.title("Distribution of movies per year")
plt.show()
# Out:
# year
# 2010    328
# 2011    399
# 2012    400
# 2013    350
# 2014    395
# 2015    450
# 2016    436
# 2017    321
# 2018    308
# Name: title, dtype: int64

# %%
#Checking out the distribution of amount of revenue earned per year
Domestic_Revenue_Year =bom_movie_df.groupby("year")["domestic_gross"].sum()
print(Domestic_Revenue_Year)
plt.figure(figsize=(10,6))
Domestic_Revenue_Year.plot(kind="bar",color="blue",edgecolor="black")
#Chart title and Labels
plt.title("Domestic Revenue by Year")
plt.xlabel("Year")
plt.ylabel("Domestic Revenue")
plt.show
# Out:
# year
# 2010    1.016393e+10
# 2011    1.006696e+10
# 2012    1.088641e+10
# 2013    1.079933e+10
# 2014    1.034334e+10
# 2015    1.105281e+10
# 2016    1.125785e+10
# 2017    1.093467e+10
# 2018    1.109121e+10
# Name: domestic_gross, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Checking out the distribution of amount of revenue earned per year
Foreign_Revenue_Year =bom_movie_df.groupby("year")["foreign_gross"].sum()
print(Foreign_Revenue_Year)
plt.figure(figsize=(10,6))
Foreign_Revenue_Year.plot(kind="bar",color="blue",edgecolor="black")
#Chart title and Labels
plt.title("Foreign Revenue by Year")
plt.xlabel("Year")
plt.ylabel("Foreign Revenue")
plt.show
# Out:
# year
# 2010    1.463606e+10
# 2011    1.765319e+10
# 2012    1.984289e+10
# 2013    1.932389e+10
# 2014    1.990787e+10
# 2015    2.004729e+10
# 2016    2.362574e+10
# 2017    2.272504e+10
# 2018    1.999900e+10
# Name: foreign_gross, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Checking the correlation between Domestic Gross and Foreign Gross
x = bom_movie_df["domestic_gross"]
y = bom_movie_df["foreign_gross"]
# Pass in x and y values with a label 
plt.scatter(x, y, label = "correlation between domestic gross and Foreign gross" )
plt.title('Relationship Between Domestic Gross and Foreign Gross')
plt.legend()

# %% [markdown]
# ### COMBINING TITLE BASICS AND TITLE RATINGS DATA FRAMES

# %%
#performing an outer merge.
Basics_ratings_df = pd.merge(title_basics_df,title_ratings_df, how = "outer", on ="tconst")
Basics_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141540 entries, 0 to 141539
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           141540 non-null  object
#  1   primary_title    140736 non-null  object
#  2   original_title   140736 non-null  object
#  3   start_year       140736 non-null  float64
#  4   runtime_minutes  140736 non-null  float64
#  5   genres           140736 non-null  object
#  6   averagerating    73856 non-null   float64
#  7   numvotes         73856 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 9.7+ MB

# %%
Basics_ratings_df = Basics_ratings_df.dropna()
Basics_ratings_df
# Out:
#            tconst                    primary_title  \
# 0       tt0063540                        Sunghursh
# 1       tt0066787  One Day Before the Rainy Season
# 2       tt0069049       The Other Side of the Wind
# 3       tt0069204                  Sabse Bada Sukh
# 4       tt0100275         The Wandering Soap Opera
# ...           ...                              ...
# 140708  tt9913056                     Swarm Season
# 140709  tt9913084                 Diabolik sono io
# 140716  tt9914286                Sokagin Çocuklari
# 140719  tt9914642                        Albatross
# 140727  tt9916160                       Drømmeland
#
#                     original_title  start_year  runtime_minutes  \
# 0                        Sunghursh      2013.0            175.0
# 1                  Ashad Ka Ek Din      2019.0            114.0
# 2       The Other Side of the Wind      2018.0            122.0
# 3                  Sabse Bada Sukh      2018.0             87.0
# ...

# %%
 Basics_ratings_df.describe()
# Out:
#          start_year  runtime_minutes  averagerating      numvotes
# count  73052.000000     73052.000000   73052.000000  7.305200e+04
# mean    2014.281430        93.956209       6.330930  3.562173e+03
# std        2.615288       198.605431       1.474699  3.045804e+04
# min     2010.000000         3.000000       1.000000  5.000000e+00
# 25%     2012.000000        83.000000       5.500000  1.400000e+01
# 50%     2014.000000        90.000000       6.500000  5.000000e+01
# 75%     2017.000000       102.000000       7.400000  2.890000e+02
# max     2019.000000     51420.000000      10.000000  1.841066e+06

# %%
plt.figure(figsize=(10,6))
genre_runtime = Basics_ratings_df.groupby("genres")["runtime_minutes"].mean().nlargest(20, "last")
print(genre_runtime)
genre_runtime.plot(kind="bar", color="blue", edgecolor="black")

#Chart title and Labels
plt.title("Average runtime by movie genre")
plt.xlabel("Genre")
plt.ylabel("Runtime")
plt.show
# Out:
# genres
# History,Musical,Romance      174.000000
# Action,Musical,Romance       170.000000
# Action,Music                 168.000000
# Comedy,History               167.666667
# Musical,Romance,Thriller     165.000000
# Adventure,Animation,Crime    157.000000
# Drama,Fantasy,Musical        156.090909
# Adventure,Horror,Romance     145.000000
# Action,Family,Thriller       145.000000
# Biography,Fantasy            140.000000
# Crime,Musical,Thriller       137.000000
# Comedy,History,Musical       134.000000
# Action,Drama,Musical         134.000000
# Action,Romance,War           133.333333
# Family,Musical,Sport         132.000000
# Action,Mystery,Western       132.000000
# Adventure,Fantasy,Musical    131.000000
# Action,Family,Mystery        131.000000
# Game-Show                    130.000000
# Crime,Documentary,Romance    130.000000
# Name: runtime_minutes, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
genre_rating = Basics_ratings_df.groupby("genres")["averagerating"].mean().nlargest(20)
#print(genre_rating)
plt.figure(figsize=(10,6))
genre_rating.plot(kind="bar",color="blue",edgecolor="black")
#Chart title and Labels
plt.title("average rating per genre")
plt.xlabel("Genre")
plt.ylabel("average rating")
# Out:
# Text(0, 0.5, 'average rating')

# %%
genre_votes = Basics_ratings_df.groupby("genres")["numvotes"].sum().nlargest(20)
#print(genre_votes)
plt.figure(figsize=(10,6))
genre_votes.plot(kind="bar",color="blue",edgecolor="black")
#Chart title and Labels
plt.title("number of votes per genre")
plt.xlabel("Genre")
plt.ylabel("number of votes")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# correlation between average rating and number of votes

# %%
x = title_ratings_df["averagerating"]
y = title_ratings_df["numvotes"]
# Pass in x and y values with a label 
plt.scatter(x, y, label = "correlation between number of votes and Average Rating" )
plt.title('Relationship Between number of votes and Average Rating')
plt.legend()
plt.show()

# %% [markdown]
# ## Merge The Basic Ratings Data Frame With The Bom Movie Data Frame

# %%
movie_df = pd.merge(Basics_ratings_df,bom_movie_df, left_on=("primary_title"), right_on =("title"))
movie_df
# Out:
#          tconst                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt4339118                      On the Road
# 3     tt5647250                      On the Road
# 4     tt0359950  The Secret Life of Walter Mitty
# ...         ...                              ...
# 3015  tt8331988                  The Chambermaid
# 3016  tt8404272           How Long Will I Love U
# 3017  tt8427036                  Helicopter Eela
# 3018  tt9078374                      Last Letter
# 3019  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year  runtime_minutes  \
# 0                               Wazir      2016.0            103.0
# 1                         On the Road      2012.0            124.0
# 2                         On the Road      2014.0             89.0
# 3                         On the Road      2016.0            121.0
# ...

# %%
#getting a new column_totalgross by combining domestic gross and foreign_gross
movie_df["total_gross"] = movie_df["domestic_gross"] + movie_df["foreign_gross"]
movie_df
# Out:
#          tconst                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt4339118                      On the Road
# 3     tt5647250                      On the Road
# 4     tt0359950  The Secret Life of Walter Mitty
# ...         ...                              ...
# 3015  tt8331988                  The Chambermaid
# 3016  tt8404272           How Long Will I Love U
# 3017  tt8427036                  Helicopter Eela
# 3018  tt9078374                      Last Letter
# 3019  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year  runtime_minutes  \
# 0                               Wazir      2016.0            103.0
# 1                         On the Road      2012.0            124.0
# 2                         On the Road      2014.0             89.0
# 3                         On the Road      2016.0            121.0
# ...

# %%
#visualizing th relationship between total revenue i.e total gross and the genres
plt.figure(figsize=(10,6))
genre_revenue = movie_df.groupby("genres")["total_gross"].sum().nlargest(20, "all")
genre_revenue.plot(kind="bar", color="blue", edgecolor="black")

#Chart title and Labels
plt.title("Revenue by movie genre")
plt.xlabel("Genre")
plt.ylabel("Revenue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#visualizing th relationship between total revenue i.e total gross and the runtime
plt.figure(figsize=(10,6))
runtime_revenue = movie_df.groupby("runtime_minutes")["total_gross"].sum().nlargest(20, "all")
print(runtime_revenue)
runtime_revenue.plot(kind="bar", color="blue", edgecolor="black")

#Chart title and Labels
plt.title("Revenue by runtime")
plt.xlabel("Runtime")
plt.ylabel("Revenue")
plt.show
# Out:
# runtime_minutes
# 98.0     6.531179e+09
# 87.0     6.327763e+09
# 105.0    6.295464e+09
# 102.0    6.251026e+09
# 130.0    6.204912e+09
# 93.0     6.177714e+09
# 103.0    5.791041e+09
# 92.0     5.778094e+09
# 100.0    5.572061e+09
# 118.0    5.482377e+09
# 97.0     5.325226e+09
# 90.0     5.186748e+09
# 95.0     5.129682e+09
# 123.0    4.784054e+09
# 108.0    4.747115e+09
# 113.0    4.673271e+09
# 106.0    4.474707e+09
# 107.0    4.376592e+09
# 124.0    4.345028e+09
# 112.0    4.307509e+09
# Name: total_gross, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## SUMMARY

# %% [markdown]
# In the Analysis above we have come to the following Conlusions:
# 1. The IFC Studio produced the highest number of movies followed by Uni then WB
# 2. 2015 produced the highest number of movies at 450, 2016:436 and 2012;400
# 3. 2016 had the highest domestic revenue, followed by 2018 then 2015
# 4. 2016 had the highest foreign revenue, followed by 2017 then 2015
# 5. The domestic revenue and foreign revenue have a strong positive correlation meaning the movies that had a high domestic revenue are more likely to have a high foreign revenue.
# 6. History,Comedy and Romance genre had the longest runtime followed by Action Musical Romance.
# 7. Comedy, Documentary and Fantasy had the highest average rating of 9.40,followed by Documentary, Family, Musical had the second highest rating of 9.30.And History and Sport had the third highest rating of 9.20.
# 8. Action, Adventure and Sci-Fi received the highest number of votes followed by Action Adventure and Animation second highest and Adventure, Animation and Comedy third highest.
# 9. There is a week correlation between number of votes and average rating, hence the number of votes do not necessarily influence the rating of a movie.
# 10. Adventure, Animation and Comedy had the highest total revenue followed by Action Adventure and Sci-fi, Then Action Adventure and Fantasy came in third.

# %% [markdown]
# ## BUSINESS RECOMMENDATIONS

# %% [markdown]
# The following are my recommendations to microsoft movie studio:
# 1. The microsoft movie studio should not produce movies with a very long runtime since the movies that have average runtime of below 100 minutes have more revenue compared to those with very high runtime.
# 2. Microsoft Movie studio should be keen to produce the following movie genres that had the most revenue:
#      a). Adventure, Animation and Comedy had the highest total
#      b). Action Adventure and Sci-fi.
#      c). Then Action Adventure and Fantasy came in third.
# 3. The genres with high number of votes are also the movie genre that attracted the highest revenue, so they should be keen to produce movies with high number of votes.This genres are:
#      a). Action, Adventure and Sci-Fi
#      b).  Action Adventure and Animation
#      c). Adventure, Animation and Comedy third highest.
# 4. Microsoft Movie studio should produce movies that will appeal to both their domestic audience and foreign audience since
#    the domestic revenue and foreign revenue have a strong positive correlation.
